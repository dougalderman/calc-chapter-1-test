# %%
x = var('x')

# %%
y = 5*x^3 - 30*x^2 + 45*x + 5*sqrt(x)

# %%
d = derivative(y, x)

# %%
d
# Out:
# 15*x^2 - 60*x + 5/2/sqrt(x) + 45

# %%
plot(y,(x, 0, 5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(d,(x, 0, 5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq = 15*x^2 - 60*x + 5/2/sqrt(x) + 45 == 0

# %%
eq.find_root(0, 5)
# Out:
# 2.9502457347345183

# %%
eq.find_root(0, 2)
# Out:
# 1.0835461956380377

# %%
eq.find_root(2, 5)
# Out:
# 2.9502457347345197

# %%
y
# Out:
# 5*x^3 - 30*x^2 + 45*x + 5*sqrt(x)

# %%
y(1.08)
# Out:
# 25.1027124227066

# %%
y(1.0835461956380377)
# Out:
# 25.10289249854833

# %%
y(2.9502457347345197)
# Out:
# 8.624656165464292

# %%
a = var('a')

# %%
f = ((sqrt(5*a + 25) - 5)/a)

# %%
f
# Out:
# (sqrt(5*a + 25) - 5)/a

# %%
plot(f,(a,-2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-f9ed1f2af2d5> in <module>
# ----> 1 f(Integer(0))
#
# /ext/sage/sage-9.3/local/lib/python3.9/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.__call__ (build/cythonized/sage/symbolic/expression.cpp:32850)()
#    5685             z^2 + x^y
#    5686         """
# -> 5687         return self._parent._call_element_(self, *args, **kwds)
#    5688
#    5689     def variables(self):
#
# /ext/sage/sage-9.3/local/lib/python3.9/site-packages/sage/symbolic/ring.pyx in sage.symbolic.ring.SymbolicRing._call_element_ (build/cythonized/sage/symbolic/ring.cpp:11478)()
#    1026                     raise ValueError("the number of arguments must be less than or equal to %s"%len(vars))
#    1027
# -> 1028         return _the_element.subs(d, **kwds)
#    1029
# ...

# %%
f(-1)
# Out:
# -2*sqrt(5) + 5

# %%
f(-0.5)
# Out:
# 0.513167019494862

# %%
f(-0.1)
# Out:
# 0.502525316941673

# %%
f(-0.01)
# Out:
# 0.500250250312906

# %%
f(-0.001)
# Out:
# 0.500025002500237

# %%
f(0.001)
# Out:
# 0.499975002499653

# %%
f(0.01)
# Out:
# 0.499750249687914

# %%
f(0.1)
# Out:
# 0.497524691810387

# %%
f(0.5)
# Out:
# 0.488088481701515

# %%
f(1)
# Out:
# sqrt(30) - 5

# %%
for a in [-1.0, -.9, -.8, .., 0]:
    print(a)
# Out:
# -1.00000000000000
# -0.900000000000000
# -0.800000000000000
# -0.700000000000000
# -0.600000000000000
# -0.500000000000000
# -0.400000000000000
# -0.300000000000000
# -0.200000000000000
# -0.100000000000000
# 0.000000000000000

# %%
for a in [-1.0, -.9, -.8, .., 1.0]:
    print(a)
# Out:
# -1.00000000000000
# -0.900000000000000
# -0.800000000000000
# -0.700000000000000
# -0.600000000000000
# -0.500000000000000
# -0.400000000000000
# -0.300000000000000
# -0.200000000000000
# -0.100000000000000
# -2.22044604925031e-16
# 0.0999999999999998
# 0.200000000000000
# 0.300000000000000
